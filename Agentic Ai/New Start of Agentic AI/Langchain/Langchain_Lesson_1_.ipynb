# %%
# !pip install langchain openai google-generativeai langchain-google-genai
from langchain_google_genai import ChatGoogleGenerativeAI
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.2/72.2 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.5/558.5 kB 20.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.9
#     Uninstalling langchain-core-1.4.9:
#       Successfully uninstalled langchain-core-1.4.9
# ...

# %%
GOOGLE_GEN_AI_API_KEY = "YOUR_GOOGLE_API_KEY"

# %%
ai = ChatGoogleGenerativeAI(temperature=0.1, google_api_key=GOOGLE_GEN_AI_API_KEY, model="gemini-3.5-flash")

# %%
from langchain_core.prompts import PromptTemplate

# %%
llm = ChatGoogleGenerativeAI(google_api_key=GOOGLE_GEN_AI_API_KEY, model = "gemini-3.5-flash")

# %%
tempate = PromptTemplate(
    input_variables=["topic"],
    template = "Explain the {topic} in hinglish"
)

# %%
prompt = tempate.format(topic = "Vector database")
response = llm.invoke(prompt)
response.content
# Out:
# [{'type': 'text',
# ...
