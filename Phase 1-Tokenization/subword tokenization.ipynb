# %%
from transformers import AutoTokenizer

# %%
tokenizer=AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.

# %%
text="Unbelivable"

# %%
tokens=tokenizer.tokenize(text)

# %%
tokens
# Out:
# ['un', '##bel', '##iva', '##ble']

# %%
words=["playing","unhappiness","transformers","qwertyxyzabc"]
for word in words:
    print(word,"->",tokenizer.tokenize(word) )
# Out:
# playing -> ['playing']
# unhappiness -> ['un', '##ha', '##pp', '##iness']
# transformers -> ['transformers']
# qwertyxyzabc -> ['q', '##wer', '##ty', '##xy', '##za', '##bc']

# %%
special_tokens = [
    "[CLS]",
    "[SEP]",
    "[PAD]",
    "[UNK]",
    "[MASK]"
]

for token in special_tokens:
    print(token, "→", tokenizer.convert_tokens_to_ids(token))
# Out:
# [CLS] → 101
# [SEP] → 102
# [PAD] → 0
# [UNK] → 100
# [MASK] → 103

# %%
print(tokenizer.tokenize("qwertyxyzabc123"))
# Out:
# ['q', '##wer', '##ty', '##xy', '##za', '##bc', '##12', '##3']
